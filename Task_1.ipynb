# %% [markdown]
# <a href="https://colab.research.google.com/github/jenika14/Task_1-Web-Scrapping/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests beautifulsoup4 pandas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
url = "http://books.toscrape.com/"
response = requests.get(url)
print("Status Code:", response.status_code)
# Out:
# Status Code: 200

# %%
soup = BeautifulSoup(response.text, "html.parser")
print(soup.prettify()[:1000])
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
books = soup.find_all("article", class_="product_pod")
data = []
for book in books:
  title = book.h3.a["title"]
  price = book.find("p", class_="price_color").text
  rating = book.find("p")["class"][1]
  data.append([title, price, rating])
print(data[:5])
# Out:
# [['A Light in the Attic', 'Â£51.77', 'Three'], ['Tipping the Velvet', 'Â£53.74', 'One'], ['Soumission', 'Â£50.10', 'One'], ['Sharp Objects', 'Â£47.82', 'Four'], ['Sapiens: A Brief History of Humankind', 'Â£54.23', 'Five']]

# %%
df = pd.DataFrame(data, columns=["Title", "Price", "Rating"])
df.head()
# Out:
#                                    Title    Price Rating
# 0                   A Light in the Attic  Â£51.77  Three
# 1                     Tipping the Velvet  Â£53.74    One
# 2                             Soumission  Â£50.10    One
# 3                          Sharp Objects  Â£47.82   Four
# 4  Sapiens: A Brief History of Humankind  Â£54.23   Five

# %%
df.to_csv("books_data.csv", index=False)
print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %%
base_url = "http://books.toscrape.com/catalogue/page-{}.html"
all_data = []
for page in range(1, 6):
    print(f"Scraping Page {page}...")
    url = base_url.format(page)
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    books = soup.find_all("article", class_="product_pod")
for book in books:
        title = book.h3.a["title"]
        price = book.find("p", class_="price_color").text
        rating = book.find("p")["class"][1]

        all_data.append([title, price, rating])
time.sleep(1)
df = pd.DataFrame(all_data, columns=["Title", "Price", "Rating"])
df.to_csv("books_full_data.csv", index=False)
print("Full dataset created!")
# Out:
# Scraping Page 1...
# Scraping Page 2...
# Scraping Page 3...
# Scraping Page 4...
# Scraping Page 5...
# Full dataset created!

# %%
for book in books:

    try:
        title = book.h3.a["title"]
    except:
        title = "Not Available"

    try:
        price = book.find("p", class_="price_color").text
    except:
        price = "Not Available"

    print(title, price)
# Out:
# Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1) Â£13.61
# Princess Between Worlds (Wide-Awake Princess #5) Â£13.34
# Pop Gun War, Volume 1: Gift Â£18.97
# Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics Â£36.28
# Patience Â£10.16
# Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1) Â£15.44
# orange: The Complete Collection 1 (orange: The Complete Collection #1) Â£48.41
# Online Marketing for Busy Authors: A Step-By-Step Guide Â£46.35
# On a Midnight Clear Â£14.07
# Obsidian (Lux #1) Â£14.86
# My Paris Kitchen: Recipes and Stories Â£33.37
# Masks and Shadows Â£56.40
# Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed Â£14.02
# Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8) Â£46.91
# Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4) Â£45.61
# ...
